# %%
import pandas as pd

# %%
mar23 = pd.read_excel('Loan Data DEC22-MAR23.xlsx',sheet_name='MAR23',header=0)

# %%
dec22 = pd.read_excel('Loan Data DEC22-MAR23.xlsx',sheet_name='DEC22',header=0)

# %%
dec22.shape
# Out:
# (85310, 24)

# %%
mar23.head()
# Out:
#   cutoff_date           loan_id        loan_group loan_program  \
# 0  2023-03-31  loan_10000000002  loan_10000071534         DRAW
# 1  2023-03-31  loan_10000000003               NaN      PRIMARY
# 2  2023-03-31  loan_10000000004  loan_10000024216         DRAW
# 3  2023-03-31  loan_10000000005               NaN      PRIMARY
# 4  2023-03-31  loan_10000000006               NaN      PRIMARY
#
#    orig_credit_score   loan_purpose_type property_type property_state  \
# 0                831    Home improvement           SFR             CA
# 1                725    Home improvement           SFR             NJ
# 2                711    Home improvement           SFR             AZ
# 3                686  Debt consolidation           SFR             CO
# 4                703  Debt consolidation           SFR             FL
#
#   lien_position  original_cltv  ...  orig_date  original_loan_term  rterm  \
# 0        Junior         0.6733  ... 2022-08-18                 172      0
# ...
